# %%
import pandas as pd
import numpy as np
from pathlib import Path
import logging
data = Path("../data/processed/Sales.csv")

# %%
df = pd.read_csv(data)
df.head()

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors = "coerce")
df['Time'] = df['Time'].astype(str)

# %%
df['Target_Total']= df['Total'] #the regression target
df['HighSpender'] = (df['Total'] > 500).astype(int) #Classification target

# %%
df["Year"]      = df["Date"].dt.year
df["Month"]     = df["Date"].dt.month
df["Day"]       = df["Date"].dt.day
df["Weekday"]   = df["Date"].dt.day_name()
df["IsWeekend"] = df["Weekday"].isin(["Saturday","Sunday"])
df['Hour'] = pd.to_datetime(df['Time'], format= "%H:%M").dt.hour
df['PartOfTheDay'] = pd.cut(df['Hour'], bins = [-1, 11, 16, 20, 24], labels=['Morning', 'Afternoon', 'Evening', 'Night'])

# %%
df_prediction = df_model.copy()

# %%
branch_features = df_model.groupby(["Branch", "City"]).agg({
    'Total': ['sum', 'mean'],
    'Quantity': 'mean',
    'Rating': 'mean',
    'Payment': lambda x: x.mode()[0]
}).reset_index()
branch_features.columns = [
    'Branch', 'City', 'Total_Sales', 'Avg_Sales',
    'Avg_Quantity', 'Avg_Rating', 'Most_Common_Payment'
]
branch_features
# Out:
#   Branch       City  Total_Sales   Avg_Sales  Avg_Quantity  Avg_Rating  \
# 0      A     Yangon  105651.3990  311.656044      5.463127    7.020944
# 1      B   Mandalay  106197.6720  319.872506      5.481928    6.818072
# 2      C  Naypyitaw  110568.7065  337.099715      5.582317    7.072866
#
#   Most_Common_Payment
# 0             Ewallet
# 1             Ewallet
# 2                Cash

# %%
customer_features = df_model.groupby('Customer_type').agg({
    'Total': ['mean', 'count'],
    'gross income': 'mean',
    'Quantity': 'mean',
    'Payment': lambda x: x.mode()[0]
}).reset_index()
customer_features.columns = [
    'Customer_type', 'Avg_Spend', 'Num_Transactions',
    'Avg_Income', 'Avg_Quantity', 'Most_Common_Payment'
]
customer_features
# Out:
#   Customer_type   Avg_Spend  Num_Transactions  Avg_Income  Avg_Quantity  \
# 0        Member  327.348945               500   15.588045      5.556000
# 1        Normal  318.122856               499   15.148707      5.460922
#
#   Most_Common_Payment
# 0         Credit card
# 1             Ewallet

# %%
# Product-level features
product_features = df_model.groupby('Product line').agg({
    'Total': 'sum',
    'Quantity': 'mean',
    'Rating': 'mean'
}).reset_index()
product_features.columns = [
    'Product_Line', 'Total_Revenue', 'Avg_Quantity', 'Avg_Rating'
]
product_features
# Out:
#              Product_Line  Total_Revenue  Avg_Quantity  Avg_Rating
# 0  Electronic accessories     54337.5315      5.711765    6.924706
# 1     Fashion accessories     54305.8950      5.067416    7.029213
# 2      Food and beverages     56144.8440      5.471264    7.113218
# 3       Health and beauty     48644.7675      5.609272    6.989404
# 4      Home and lifestyle     53861.9130      5.693750    6.837500
# 5       Sports and travel     55122.8265      5.542169    6.916265

# %%
branch_avg = df_model.groupby("Branch")['Total'].mean().rename("Branch_Avg_Sales")
df_model = df_model.merge(branch_avg, on="Branch")
df_model.head()
# Out:
#   Branch       City Customer_type  Gender            Product line  Unit price  \
# 0      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 1      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 2      A     Yangon        Member    Male       Health and beauty       58.22
# 3      A     Yangon        Normal    Male       Sports and travel       86.31
# 4      C  Naypyitaw        Normal    Male  Electronic accessories       85.39
#
#    Quantity     Total      Payment  gross income  ...    Year  Month  Day  \
# 0         5   80.2200         Cash        3.8200  ...  2021.0    8.0  3.0
# 1         7  340.5255  Credit card       16.2155  ...  2021.0    3.0  3.0
# 2         8  489.0480      Ewallet       23.2880  ...     NaN    NaN  NaN
# 3         7  634.3785      Ewallet       30.2085  ...  2021.0    8.0  2.0
# 4         7  627.6165      Ewallet       29.8865  ...     NaN    NaN  NaN
#
#      Weekday  IsWeekend  Hour PartOfTheDay  Average_price_Item  \
# 0    Tuesday      False    10      Morning             16.0440
# 1  Wednesday      False    13    Afternoon             48.6465
# 2        NaN      False    20      Evening             61.1310
# 3     Monday      False    10      Morning             90.6255
# 4        NaN      False    18      Evening             89.6595
#
#    Branch_Avg_Sales_x Branch_Avg_Sales_y
# 0          337.099715         337.099715
# 1          311.656044         311.656044
# 2          311.656044         311.656044
# 3          311.656044         311.656044
# 4          337.099715         337.099715
#
# [5 rows x 23 columns]

# %%
def simple_encode(df):
    cat_cols = df.select_dtypes(include=['object','category']).columns
    df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)
    return df_encoded

df_model_encoded = simple_encode(df_model)

# %%
df_model_encoded.to_csv('Sales_encoded.csv')
